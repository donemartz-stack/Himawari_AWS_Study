# %% [markdown]
# Write a Python code that will extract the band 14 and band 15 brightness temperature from Himawari AHI through the AWS S3 at the exact location 14.77083, 120.45537 for the period of March to May 2025. The output file must be saved in CSV format. Keep the code simple and clean with proper comments.

# %% [markdown]
# Tell me how I can extract the band 14 and band 15 brightness temperature from Himawari AHI through the AWS S3 at the exact location 14.77083, 120.45537 for the period of March to May 2025.

# %% [markdown]
# cd /Users/danwilliammartinez/Desktop/Himawari_AWS_Study/himawari_B13_B14_202503_202505
# bunzip2 *.bz2
