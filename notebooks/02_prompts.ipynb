# %% [markdown]
# This is my weather data. Please write Python code that extracts the average of each parameter in the columns every 10 minutes. The input file is in XLXS format. The output file must be in XLSX format, and I should be able to specify the folder where it will be saved. Keep the code clean and simple with necessary comments.

# %% [markdown]
#  I have processed weather data. Please write Python code that plots each weather parameter as a time series. The plots must be saved in a single PNG file, and I should be able to specify the folder where it will be saved. Keep the code clean and simple, with necessary comments.

# %% [markdown]
# Please write Python code that combines the following datasets and matches the timestamp. The input files are in XLXS format. The output file must be in XLSX format, and I should be able to specify the folder where it will be saved. Keep the code clean and simple with necessary comments.

# %% [markdown]
# You said
# Please write Python code that extracts 10AM to 4PM data from the given dataset, excludes rows with band 14 brightness temperature lower than 16, temperature difference above 4.0, and humidity value below 40% and above 85%. The input file is in XLXS format. The output file must be in XLSX format, and I should be able to specify the folder where it will be saved. Keep the code clean and simple with necessary comments.
